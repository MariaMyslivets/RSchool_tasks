# %% [markdown]
# # Overfitting and Regularization

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, cross_validate
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import mean_squared_error
from sklearn import set_config
from sklearn.preprocessing import StandardScaler
import warnings
from tqdm import tqdm

# %%
# !pip install scikit-learn-intelex
from sklearnex import patch_sklearn, config_context
patch_sklearn()
# Out:
# ...
#      |████████████████████████████████| 69 kB 3.0 MB/s
# ...
#      |████████████████████████████████| 22.5 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 284.3 MB 1.6 kB/s
# ...
#      |████████████████████████████████| 4.0 MB 26.3 MB/s
# ...
# Intel(R) Extension for Scikit-learn* enabled (https://github.com/intel/scikit-learn-intelex)

# %%
set_config(display='diagram')

# %% [markdown]
# ## Settings

# %%
SEED = 42
RANGE = (-5, 5)
N_SAMPLES = 50
DEGREES = np.linspace(0, 15, 1 + 15, dtype=int)
ALPHAS = np.linspace(0, 0.5, 1 + 40)

# %% [markdown]
# ## Part 1: Underfitting vs. overfitting

# %% [markdown]
# ### Generate samples

# %% [markdown]
# Let's pick a target function $ f(x) = 2\cdot x + 10\cdot sin(x) $ and generate some noisy samples to learn from.

# %%
def target_function(x):
    return 2 * x + 10 * np.sin(x)

def generate_samples():
    """Generate noisy samples."""
    np.random.seed(SEED)
    x = np.random.uniform(*RANGE, size=N_SAMPLES)
    y = target_function(x) + np.random.normal(scale=4, size=N_SAMPLES)
    return x.reshape(-1, 1), y

X, y = generate_samples()

# %% [markdown]
# ### Plot samples

# %%
def plot_scatter(x, y, title=None, label='Noisy samples'):
    plt.scatter(x, y, label=label)
    plt.xlabel('x')
    plt.ylabel('y')
    plt.grid(True)
    plt.title(title)
    plt.legend(loc='lower right')

plot_scatter(X, y)

# %% [markdown]
# ### Split

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.3, random_state=SEED)

plot_scatter(X_train, y_train, label='Training set')
plot_scatter(X_valid, y_valid, label='Validation set')

# %%
y_train
# Out:
# array([ -1.10771616,   0.84986647,  -9.62110024,   3.70972424,
#         -2.36319095,   5.83708039, -16.53330524,  -1.8815588 ,
#        -11.1506254 ,   1.0883081 ,  -9.05957818, -14.72254274,
#          5.71746212,   5.48508317,  -6.81897956,  -1.80751907,
#         -2.14124891, -12.83476672,  -0.09034969,  -3.48222266,
#         11.50001273,  -2.03019037,  10.03142993, -17.18409407,
#         -2.48182149,   1.67461593, -17.32081894,  -6.32825039,
#         -4.15121484,   9.31494651,   6.5817456 ,   6.58351686,
#         -1.83803375,  11.27589865,  13.68530977])

# %% [markdown]
# ### Model

# %% [markdown]
# Let's try to approximate our target function $ f(x) = 2\cdot x + 10\cdot sin(x) $ with polynomials of different degree.
#
# A polynomial of degree $n$ has the form:
# $ h(x) = w_0 + w_1\cdot x + w_2\cdot x^2 +\ldots + w_n\cdot x^n $.
#
# $x^i$ values could easily be generated by `PolynomialFeatures`, while $w_i$ are the unknown paramaters to be estimated using `LinearRegression`.

# %%
PolynomialFeatures(degree=4, include_bias=False).fit_transform(X=[
    [1],
    [3],
    [4],
])
# Out:
# array([[  1.,   1.,   1.,   1.],
#        [  3.,   9.,  27.,  81.],
#        [  4.,  16.,  64., 256.]])

# %%
def make_model(degree, alpha=0, penalty=None):
    # linear regression
    if alpha == 0:
        regressor = LinearRegression()
    # lasso regression",
    elif penalty == 'L1':
        regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=50000)
    # ridge regression",
    elif penalty == 'L2':
        regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=50000) 
    
    
    return Pipeline([
        ('pol', PolynomialFeatures(degree, include_bias=(degree == 0))),
        ('sca', StandardScaler()),
        ('reg', regressor)
    ])

display(make_model(2))
display(make_model(2, penalty='L1', alpha=0.1))
display(make_model(2, penalty='L2', alpha=0.1))
# Out:
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()), ('reg', LinearRegression())])
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()),
#                 ('reg', Lasso(alpha=0.1, max_iter=50000, random_state=42))])
# Pipeline(steps=[('pol', PolynomialFeatures(include_bias=False)),
#                 ('sca', StandardScaler()),
#                 ('reg', Ridge(alpha=0.1, max_iter=50000, random_state=42))])

# %% [markdown]
# ### Fit

# %% [markdown]
# Let's fit a model and plot the hypothesis it learns:

# %%
def plot_fit(model):
    degree = model['pol'].degree
    X_range = np.linspace(*RANGE, 1000).reshape(-1, 1)
    y_pred = model.predict(X_range)
    plot_scatter(X_train, y_train, label='Training sample')
    plot_scatter(X_valid, y_valid, label='Validation sample')
    plt.plot(X_range, target_function(X_range), c='green', alpha=0.2, lw=5, label='Target function')
    plt.plot(X_range, y_pred, c='red', label='Hypothesis')
    plt.ylim((min(y) - 3, max(y) + 3))
    plt.legend(loc='best')    
    plt.title(f'Polynomial approximation: degree={degree}')
    plt.show()

plot_fit(make_model(degree=2).fit(X_train, y_train))

# %% [markdown]
# ### From underfitting to overfitting

# %% [markdown]
# We can investigate the shape of the fitted curve for different values of `degree`:

# %%
for degree in [0, 1, 2, 3, 4, 5, 10, 15, 20]:
    plot_fit(make_model(degree).fit(X_train, y_train))

# %% [markdown]
# ### Fitting graph

# %% [markdown]
# In the next step we calculate the training and the validation error for each `degree` and plot them in a single graph. The resulting graph is called the fitting graph.

# %%
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

def plot_fitting_graph(x, metric_train, metric_valid, xlabel, ylabel, 
                       custom_metric=None, custom_label='', custom_scale='log', title='Fitting graph'):
    plt.figure(figsize=(9, 4.5))
    plt.plot(x, metric_train, label='Training')
    plt.plot(x, metric_valid, color='C1', label='Validation')
    plt.axvline(x[np.argmin(metric_valid)], color='C1', lw=10, alpha=0.2)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.xticks(x, rotation='vertical')
    plt.legend(loc='center left')        
    if custom_metric:
        plt.twinx()
        plt.yscale(custom_scale)
        plt.plot(x, custom_metric, alpha=0.2, lw=4, ls='dotted', color='black', label=custom_label) 
        plt.legend(loc='center right')         
    plt.show()
    
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    reg = make_model(degree).fit(X_train, y_train)
    rmse_train.append(rmse(reg.predict(X_train), y_train))
    rmse_valid.append(rmse(reg.predict(X_valid), y_valid))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)', 
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Sweet spot

# %% [markdown]
# What is the optimal `degree` to go with?

# %%
DEGREES[np.argmin(rmse_valid)]
# Out:
# 5

# %% [markdown]
# ### Cross-validation

# %% [markdown]
# Ideally, we would choose the the model parameters such that we have the best model performance. However, we want to make sure that we really have the best validation performance. When we do `train_test_split` we randomly split the data into two parts. What could happen is that we got lucky and split the data such that it favours the validation error. This is especially dangerous if we are dealing with small datasets. One way to check if that's the case is to run the experiment several times for different, random splits. However, there is an even more systematic way of doing this: [cross-validation](https://scikit-learn.org/stable/modules/cross_validation.html).

# %% [markdown]
# <img src="https://scikit-learn.org/stable/_images/grid_search_cross_validation.png" width=50% />

# %%
rmse_train, rmse_valid = [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Model coefficients

# %% [markdown]
# Let's inspect our regression model coefficients:

# %%
(make_model(degree=1).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=2).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=5).fit(X_train, y_train)['reg'].coef_,
 make_model(degree=10).fit(X_train, y_train)['reg'].coef_)
# Out:
# (array([2.81292778]),
#  array([2.80049884, 0.45166501]),
#  array([ 30.87315584,   1.48752361, -54.60227825,  -1.63699842,
#          26.62792933]),
#  array([  33.63850705,  -41.86346242,  -70.48743112,  278.98853452,
#           27.48125634, -656.36383501,   59.32988346,  651.64795186,
#          -47.55728814, -233.48455138]))

# %% [markdown]
# Hmm... it looks like high degree polynomials are coming with much bigger regression coefficients.
#
# We are going to plot the mean absolute value of $w_i$ as a function of degree to reveal the relationship:

# %%
rmse_train, rmse_valid, avg_coef = [], [], []
for degree in DEGREES:
    results = cross_validate(make_model(degree),
                             X, y, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))        
    avg_coef.append(        
        # average over CV folds
        np.mean([            
            # mean absolute value of weights
            np.mean(np.abs(model['reg'].coef_))
            for model in results['estimator']
        ]))
    
plot_fitting_graph(DEGREES, rmse_train, rmse_valid,
                   xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef, custom_label='avg(|$w_i$|)',
                   title='Least squares polynomial regression')

# %% [markdown]
# ### Summary

# %% [markdown]
# We observe the following:
#
# 1. **Underfitting** (degree < 5): The model is not able to fit the data properly. The fit is bad for both the training and the validation set.
#
# 2. **Fit is just right** (degree = 5): The model is able to capture the underlying data distribution. The fit is good for both the training and the validation set.
#
# 3. **Overfitting** (degree > 5): The model starts fitting the noise in the dataset. While the fit for the training data gets even better, the fit for the validation set gets worse.
#
# 4. As the order of polynomial increases, the linear model coefficients become more likely to take on **large values**.

# %% [markdown]
# ## Part 2: Regularization

# %% [markdown]
# There are two major ways to build a machine learning model with the ability to generalize well on unseen data:
# 1. Train the simplest model possible for our purpose (according to Occam’s Razor).
# 2. Train a complex or more expressive model on the data and perform regularization.
#
# Regularization is a method used to reduce the variance of a machine learning model. In other words, it is used to reduce overfitting. Regularization penalizes a model for being complex. For linear models, it means regularization forces model coefficients to be smaller in magnitude.
#
# Let's pick a polynomial model of degree **15** (which tends to overfit strongly) and try to regularize it using **L1** and **L2** penalties.

# %% [markdown]
# ### L1 - Lasso regression

# %%
rmse_train, rmse_valid = [], []
for alpha in ALPHAS:    
    results = cross_validate(make_model(degree=15, penalty='L1', alpha=alpha), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid,
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)',
                   title='Lasso polynomial regression (L1): degree=15')

# %% [markdown]
# ### L2 - Ridge regression

# %%
rmse_train, rmse_valid = [], []
for alpha in ALPHAS:    
    results = cross_validate(make_model(degree=15, penalty='L2', alpha=alpha), 
                             X, y, cv=5,
                             return_train_score=True,
                             scoring='neg_root_mean_squared_error')
    rmse_train.append(-np.mean(results['train_score']))
    rmse_valid.append(-np.mean(results['test_score']))
    
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid, 
                   xlabel='Regularization strength (alpha)', ylabel='Error (RMSE)', 
                   title='Ridge polynomial regression (L2): degree=15')

# %% [markdown]
# ### Summary

# %% [markdown]
# 1. We can control the regularization strength by changing the hyperparameter `alpha`.
# 2. Regularized version of the model performs pretty well. Even in case the original original (unregularized) model is heavily overfitting due to excessive complexity.

# %% [markdown]
# ## Part 3: Homework assignment (10 points)

# %% [markdown]
# ### Excercise 1 - Overfiting and Underfitting (2 points)

# %% [markdown]
# Let's work with the diabetes dataset

# %%
from sklearn.datasets import load_diabetes
data = load_diabetes()
X_diabetes = pd.DataFrame(data['data'], columns=data['feature_names'])
y_diabetes = pd.DataFrame(data['target'], columns=['target'])
print(data['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
#   :Number of Instances: 442
#
#   :Number of Attributes: First 10 columns are numeric predictive values
#
#   :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
#   :Attribute Information:
#       - age     age in years
#       - sex
#       - bmi     body mass index
#       - bp      average blood pressure
#       - s1      tc, total serum cholesterol
#       - s2      ldl, low-density lipoproteins
#       - s3      hdl, high-density lipoproteins
#       - s4      tch, total cholesterol / HDL
#       - s5      ltg, possibly log of serum triglycerides level
# ...

# %% [markdown]
# Apply model for diabetes dataset with polynomial feature engineering of different degrees. Plot the dependence of train and test error on polynomial degree. Highlight a degree with the best test error. Which degrees cause overfitting/underfitting? Why?

# %%
X_tr = X_diabetes.drop(['s5','s6'],axis=1)

# %%
rmse_train, rmse_valid = [], []
for degree in tqdm(DEGREES):
    if degree != 0:
        poly = PolynomialFeatures(degree)
        X_tr_pol = poly.fit_transform(X_tr)
        X_tr_pol = np.column_stack((X_tr_pol,X_diabetes[['s5','s6']].to_numpy().reshape((442,2))))
        sc = StandardScaler()
        X_tr_sc = sc.fit_transform(X_tr_pol)
        lr = LinearRegression()
        results = cross_validate(lr, 
                                 X_tr_sc, y_diabetes, cv=5,
                                 return_train_score=True,
                                 scoring='neg_root_mean_squared_error')
        rmse_train.append(-np.mean(results['train_score']))
        rmse_valid.append(-np.mean(results['test_score']))
    
    
plot_fitting_graph(DEGREES[1:], rmse_train, rmse_valid, xlabel='Complexity (degree)', ylabel='Error (RMSE)',
                   title='Least squares polynomial regression')
# Out:
# 100%|██████████| 16/16 [15:50<00:00, 59.40s/it]

# %% [markdown]
# Due to the heavy load on the system during the calculations, it was necessary to reduce the number of features that were polynomialized, and also for the same reason cross-validation was not carried out.
#
# From the above figure, we can conclude that explicit retraining of the model begins to be observed after the 3rd degree. For degrees 1 and 2, the best result of the metric RMSE is obtained.

# %% [markdown]
# ### Excercise 2 - Magnitude (3 points)

# %% [markdown]
# As discussed earlier, regularization methods are expected to constraint the weights (model coefficients).
#
# Is it indeed happening?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**). Let's use `degree=15` and `alpha` from `ALPHAS`.

# %%
x_tr, x_val, y_tr, y_val = train_test_split(X_diabetes, y_diabetes, test_size = 0.3, random_state=SEED)

# %%
X_tr, X_val = x_tr.drop(['s3','s4','s5','s6'],axis=1), x_val.drop(['s3','s4','s5','s6'],axis=1)

# %%
def explore_reg(degree, data_train, data_val, cols):
  poly = PolynomialFeatures(degree)
  X_tr_pol = poly.fit_transform(data_train)
  X_tr_pol = np.column_stack((X_tr_pol,x_tr[cols].to_numpy()))
  X_v_pol = poly.transform(data_val)
  X_v_pol = np.column_stack((X_v_pol,x_val[cols].to_numpy()))
  sc = StandardScaler()
  X_tr_sc = sc.fit_transform(X_tr_pol)
  X_v_sc = sc.transform(X_v_pol)
  return X_tr_sc, X_v_sc
def model_learn_pred(penalty, alpha, X_train, X_val,max_iter):
  if penalty == 'L1':
    regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=max_iter)
    # ridge regression",
  elif penalty == 'L2':
    regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=max_iter)
  
  regressor.fit(X_train, y_tr)
  pred_tr = regressor.predict(X_train)
  pred_val = regressor.predict(X_val)
  return pred_tr, pred_val, regressor

# %% [markdown]
# #### L1

# %%
rmse_train, rmse_valid, avg_coef, coeff = [], [], [], []
X_tr_sc, X_v_sc = explore_reg(15, X_tr, X_val, ['s3','s4','s5','s6'])
for alpha in tqdm(ALPHAS):
  pred_tr, pred_val, lr_1 =  model_learn_pred('L1',alpha, X_tr_sc, X_v_sc,7000)
           
  rmse_train.append(mean_squared_error(y_tr,pred_tr)**0.5)
  rmse_valid.append(mean_squared_error(y_val,pred_val)**0.5)        
  avg_coef.append(np.mean(np.concatenate((lr_1.intercept_,lr_1.coef_))))
      
  coeff.append(np.concatenate((lr_1.intercept_,lr_1.coef_), axis=None))
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.978e+03, tolerance: 1.900e+02 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# ...

# %%
plot_fitting_graph(ALPHAS, rmse_train, rmse_valid,
                   xlabel='Complexity (ALPHAS)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef, custom_label='avg(|$w_i$|)',
                   title='Lasso')

# %% [markdown]
# It can be seen from the figure that with an increase in the regularization coefficient, the average value of the model weights remains approximately the same in the range of one tenth, which indicates that Lasso constraints the weights. Moreover, the metrics of the training and validation samples converge.

# %% [markdown]
# #### L2

# %%
## your code
rmse_train_2, rmse_valid_2, avg_coef_2, avg_coef_20, coeff_2 = [], [], [], [], []
X_tr_sc, X_v_sc = explore_reg(15, X_tr, X_val, ['s3','s4','s5','s6'])
for alpha in tqdm(ALPHAS):
  pred_tr_2, pred_val_2, lr_2 =  model_learn_pred('L2', alpha, X_tr_sc, X_v_sc,10000)
           
  rmse_train_2.append(mean_squared_error(y_tr,pred_tr_2)**0.5)
  rmse_valid_2.append(mean_squared_error(y_val,pred_val_2)**0.5)        
  avg_coef_2.append(np.mean(np.concatenate((lr_2.intercept_,lr_2.coef_), axis=None)))
  avg_coef_20.append(np.mean(lr_2.coef_))
      
  coeff_2.append(np.concatenate((lr_2.intercept_,lr_2.coef_), axis=None))
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:194: LinAlgWarning: Ill-conditioned matrix (rcond=2.03372e-19): result may not be accurate.
#   dual_coef = linalg.solve(K, y, sym_pos=True, overwrite_a=False)
# 100%|██████████| 41/41 [00:18<00:00,  2.27it/s]

# %%
plot_fitting_graph(ALPHAS, rmse_train_2, rmse_valid_2,
                   xlabel='Complexity (ALPHAS)', ylabel='Error (RMSE)',
                   custom_metric=avg_coef_20, custom_label='avg(|$w_i$|)',
                   title='Ridge')

# %% [markdown]
# The Ridge model for metrics showed a worse result, taking into account the selected features, but model also constraints the weights.

# %% [markdown]
# #### Summary

# %% [markdown]
# With the help of the study, it was demonstrated that with an increase in the regularization coefficient, the weights of the models don't change extreme. And this procedure helps to improve the results obtained, namely, the model becomes less prone to overfitting.

# %% [markdown]
# ### Excercise 3 - Sparsity (3 points)

# %% [markdown]
# Lasso can also be used for **feature selection** since L1 is [more likely to produce zero coefficients](https://explained.ai/regularization/).
#
# Is it indeed happening?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**). Let's use `degree=15` and `alpha` from `ALPHAS`.

# %% [markdown]
# #### L1

# %%
count_zero = [round((1 - np.count_nonzero(x)/len(coeff[0]))*100,5) for x in coeff]
sns.relplot(x=ALPHAS, y=count_zero, kind="line")
plt.title('Zero weights with using Lasso', fontsize = 16)
plt.xlabel('Alphas', fontsize = 14)
plt.ylabel('Percentage of zero weights, %', fontsize = 14)
plt.grid()
plt.show()

# %% [markdown]
# This image confirms that when using Lasso and changing the regularization coefficient, some less important features are reset to zero.

# %% [markdown]
# #### L2

# %%
count_zero_2 = [round((1 - np.count_nonzero(x)/len(coeff_2[0]))*100,5) for x in coeff_2]
sns.relplot(x=ALPHAS, y=count_zero_2, kind="line")
plt.title('Zero weights with using Ridge', fontsize = 16)
plt.xlabel('Alphas', fontsize = 14)
plt.ylabel('Percentage of zero weights, %', fontsize = 14)
plt.grid()
plt.show()

# %% [markdown]
# When used Ridge, the weights change (demonstrated in the image in the previous task), but their zeroing and featuress don't occur.

# %% [markdown]
# #### Summary

# %% [markdown]
# As a result of the research, we can conclude that, indeed, when using Lasso, less important features are set to zero, which can be used to select more important features.

# %% [markdown]
# ### Excercise 4 - Scaling (2 points)

# %% [markdown]
# As a general rule, it is recommended to scale input features before fitting a regularized model so that the features/inputs take values in similar ranges. One common way of doing so is to standardize the inputs and that is exactly what our pipeline  second step (`StandardScaler`) is responsible for.
#
# Is scaling important? What are the underlying reasons?
#
# Please do a discovery on your own and find that out empirically (both for **L1** and **L2**) on the dataset below. Check coefficients.

# %%
def target_function_hw(x):
    return 2 * x

def generate_samples_hw():
    np.random.seed(SEED)
    x = np.random.uniform(*RANGE, size=N_SAMPLES)
    
    np.random.seed(SEED+1)
    x_noise = np.random.uniform(*[x * 100 for x in RANGE], size=N_SAMPLES)
    x_noise2 = np.random.normal(100, 50, size=N_SAMPLES)
    
    y = target_function_hw(x) + np.random.normal(scale=4, size=N_SAMPLES)
    
    return np.concatenate([x.reshape(-1, 1) / 100, 
                           x_noise.reshape(-1, 1),
                           x_noise2.reshape(-1, 1)], axis=1), y

X_hw, y_hw = generate_samples_hw()

for i in range(X_hw.shape[1]):
    print(f'Min of feature {i}: {min(X_hw[:, i]):.2f}, max: {max(X_hw[:, i]):.2f}')
# Out:
# Min of feature 0: -0.05, max: 0.05
# Min of feature 1: -494.87, max: 493.57
# Min of feature 2: -2.35, max: 213.31

# %%
def make_model_task4(degree, scal, alpha=0, penalty=None):
    # linear regression
    if penalty == 'L1':
        regressor = Lasso(alpha=alpha, random_state=SEED, max_iter=50000)
    # ridge regression",
    elif penalty == 'L2':
        regressor = Ridge(alpha=alpha, random_state=SEED, max_iter=50000) 
    
    if scal == True:
        return Pipeline([
            ('pol', PolynomialFeatures(degree, include_bias=(degree == 0))),
            ('sca', StandardScaler()),
            ('reg', regressor)
            ])
    else:
        return Pipeline([
            ('pol', PolynomialFeatures(degree, include_bias=(degree == 0))),
            ('reg', regressor)
            ])

# %% [markdown]
# #### L1

# %%
## your code
results = cross_validate(make_model_task4(15,scal=True,alpha=0.03, penalty = 'L1'),
                         X, y, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
rmse_tr_l1_t = -np.mean(results['train_score'])
rmse_v_l1_t = -np.mean(results['test_score'])        
avg_c_l1_t = np.mean([np.mean(np.abs(model['reg'].coef_)) for model in results['estimator']])
print(f'RMSE for standardized train sample Lasso model: {round(rmse_tr_l1_t,3)}')
print(f'RMSE for no standardized validation sample Lasso model: {round(rmse_v_l1_t,3)}')
# Out:
# RMSE for standardized train sample Lasso model: 3.562
# RMSE for no standardized validation sample Lasso model: 4.349

# %%
## your code
results = cross_validate(make_model_task4(15, scal = False,alpha=0.03, penalty = 'L1'),
                         X, y, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
rmse_tr_l1_f = -np.mean(results['train_score'])
rmse_v_l1_f= -np.mean(results['test_score'])        
avg_c_l_f = np.mean([np.mean(np.abs(model['reg'].coef_)) for model in results['estimator']])
print(f'RMSE for standardized train sample Lasso model: {round(rmse_tr_l1_f,3)}')
print(f'RMSE for no standardized validation sample Lasso model: {round(rmse_v_l1_f,3)}')
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.043e+02, tolerance: 3.015e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_coordinate_descent.py:648: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.154e+02, tolerance: 3.290e-01
#   coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
# ...

# %% [markdown]
# #### L2

# %%
## your code
results = cross_validate(make_model_task4(15,scal=True, alpha=0.03, penalty = 'L2'),
                         X, y, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
rmse_tr_l2_t = -np.mean(results['train_score'])
rmse_v_l2_t = -np.mean(results['test_score'])        
avg_c_l2_t = np.mean([np.mean(np.abs(model['reg'].coef_)) for model in results['estimator']])
print(f'RMSE for standardized train sample Lasso model: {round(rmse_tr_l2_t,3)}')
print(f'RMSE for no standardized validation sample Lasso model: {round(rmse_v_l2_t,3)}')
# Out:
# RMSE for standardized train sample Lasso model: 3.438
# RMSE for no standardized validation sample Lasso model: 4.659

# %%
## your code
results = cross_validate(make_model_task4(15,scal=False,alpha=0.03, penalty = 'L2'),
                         X, y, cv=5,
                             return_train_score=True, return_estimator=True,
                             scoring='neg_root_mean_squared_error')
rmse_tr_l2_f = -np.mean(results['train_score'])
rmse_v_l2_f = -np.mean(results['test_score'])        
avg_c_l2_f = np.mean([np.mean(np.abs(model['reg'].coef_)) for model in results['estimator']])
print(f'RMSE for standardized train sample Lasso model: {round(rmse_tr_l2_f,3)}')
print(f'RMSE for no standardized validation sample Lasso model: {round(rmse_v_l2_f,3)}')
# Out:
# RMSE for standardized train sample Lasso model: 2.84
# RMSE for no standardized validation sample Lasso model: 8.588
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.6484e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=4.32488e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.69011e-22): result may not be accurate.
#   return linalg.solve(A, Xy, sym_pos=True, overwrite_a=True).T
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_ridge.py:157: LinAlgWarning: Ill-conditioned matrix (rcond=2.76736e-22): result may not be accurate.
# ...

# %%
res_all = np.array([['Lasso StandartSc = True', round(rmse_tr_l1_t,3), round(rmse_v_l1_t,3)], 
                       ['Lasso StandartSc = False', round(rmse_tr_l1_f,3), round(rmse_v_l1_f)],
                    ['Ridge StandartSc = True', round(rmse_tr_l2_t,3), round(rmse_v_l2_t)],
                    ['Ridge StandartSc = False', round(rmse_tr_l2_f,4), round(rmse_v_l2_f,4)]])
result_all = pd.DataFrame(res_all,columns = ['model','RMSE_train', 'RMSE_val'])

# %%
result_all
# Out:
#                       model RMSE_train RMSE_val
# 0   Lasso StandartSc = True      3.562    4.349
# 1  Lasso StandartSc = False      3.124        5
# 2   Ridge StandartSc = True      3.438        5
# 3  Ridge StandartSc = False       2.84   8.5882

# %% [markdown]
# #### Summary

# %% [markdown]
# The table shows that when using Lasso, the metrics with and without feature standardization differ, but not critically. Although with standardization, the difference RMSEs are smaller, which indicates a lesser degree of overfitting than without standardization. But most likely, the small difference between the results obtained was trained by nulling unimportant features in both cases.
#
# When using Ridge, the difference in metrics with and without standardization is more obvious. And it demonstrates that the model is heavily overfitted without the use of feature standardization.
